# %%
pip install gensim
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.6/26.6 MB 50.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 54.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 8.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.1
#     Uninstalling scipy-1.16.1:
#       Successfully uninstalled scipy-1.16.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
import numpy as np
import pandas as pd
from gensim.test.utils import datapath, get_tmpfile
from gensim.models import KeyedVectors

# %%
glove_file = datapath("/content/drive/MyDrive/books/glove.twitter.27B.50d.txt") # Source: Methoden der Angewandte Computerlinguistik - Kapitel 8
model = KeyedVectors.load_word2vec_format(glove_file, binary=False, no_header=True)

# %%
books_data = pd.read_csv("/content/drive/MyDrive/books/books_1.Best_Books_Ever.csv", usecols=['title', 'author', 'rating', 'numRatings' , 'description', 'language', 'genres'])
# Actual data is in books/books_1.Best_Books_Ever.csv, books_modified.csv contains dataset with keywords extracted from description with keybert . The extraction takes almost an hour, hence I saved the dataset under another name to save time

books_data.head(5)
# Out:
#                                        title  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 2                      To Kill a Mockingbird
# 3                        Pride and Prejudice
# 4                                   Twilight
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                 Harper Lee    4.28
# 3  Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                            Stephenie Meyer    3.60
#
#                                          description language  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English
# 1  There is a door at the end of a silent corrido...  English
# 2  The unforgettable novel of a childhood in a sl...  English
# 3  Alternate cover edition of ISBN 9780679783268S...  English
# ...

# %%
books_data.drop_duplicates(subset=['title'], inplace=True)

# %%
books_data["length"] = books_data['description'].apply(lambda d: len(d.split()) if isinstance(d, str) else 0)
books_data = books_data[books_data["length"] >= 4].copy()

books_data.drop(columns=["length"])
# Out:
#                                                    title  \
# 0                                       The Hunger Games
# 1              Harry Potter and the Order of the Phoenix
# 2                                  To Kill a Mockingbird
# 3                                    Pride and Prejudice
# 4                                               Twilight
# ...                                                  ...
# 52468                                      Nameless Fate
# 52469  Heal Your Body: The Mental Causes for Physical...
# 52470                                  Attracted to Fire
# 52474                                            Anasazi
# 52477                                Daughter of Helaman
#
#                                           author  rating  \
# 0                                Suzanne Collins    4.33
# 1      J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                     Harper Lee    4.28
# ...

# %%
books_data.dropna(subset=["description"], inplace=True)

# %%
import ast

books_data['genres'] = books_data['genres'].apply(ast.literal_eval)
# Using AI because turns out genres is a string of a list and not a list

# Apply lambda function to lowercase all genres, making comparison with user input easier
books_data['genres'] = books_data['genres'].apply(lambda x: [genre.lower() for genre in x])

# %%
books_data['title'].count()
# Out:
# 48452

# %%
books_data.head()
# Out:
#                                        title  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 2                      To Kill a Mockingbird
# 3                        Pride and Prejudice
# 4                                   Twilight
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                 Harper Lee    4.28
# 3  Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                            Stephenie Meyer    3.60
#
#                                          description language  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English
# 1  There is a door at the end of a silent corrido...  English
# 2  The unforgettable novel of a childhood in a sl...  English
# 3  Alternate cover edition of ISBN 9780679783268S...  English
# ...

# %%
type(books_data['author'][0])
# Out:
# str

# %%
books_data['author'] = books_data['author'].apply(lambda x: x.lower())

# %%
books_data['author'].head()
# Out:
# 0                              suzanne collins
# 1    j.k. rowling, mary grandpré (illustrator)
# 2                                   harper lee
# 3    jane austen, anna quindlen (introduction)
# 4                              stephenie meyer
# Name: author, dtype: object

# %%
books_data['rating_total'] = books_data['rating'] * books_data['numRatings']
books_data['rating_total'].head()
# Out:
# 0    27611457.40
# 1    11284303.50
# 2    19264601.00
# 3    12772506.66
# 4    17872268.40
# Name: rating_total, dtype: float64

# %% [markdown]
# Next step: Represent book as vectors through their description.
#
# Extract keywords from the description and transform them to vectors by averaging the GloVe vector. -- Geeksforgeeks method
# Train a text classifier to predict genre from keywords?
# Or just put the vectors to a kNN Classifier. (I\s this accurate?)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(token_pattern=r'(?u)\b[a-zA-Z]+\b', stop_words='english')

tfidf_matrix = vectorizer.fit_transform(books_data['description'])

feature_names = np.array(vectorizer.get_feature_names_out())

feature_names
# Out:
# array(['aa', 'aaa', 'aaaa', ..., 'zzes', 'zzysra', 'zzyxx'], dtype=object)

# %%
def get_top_keywords(row_idx, top_n=5):
    row = tfidf_matrix.getrow(row_idx)
    nonzero_idx = row.nonzero()[1]
    scores = row.data
    top_indices = scores.argsort()[::-1][:top_n]
    top_keywords = feature_names[nonzero_idx][top_indices]
    return top_keywords.tolist()

books_data['keywords'] = [get_top_keywords(i, top_n=5) for i in range(len(books_data))]

print(books_data['keywords'].head(10))
# Out:
# 0         [katniss, districts, games, capitol, hunger]
# 1       [harry, hogwarts, gryffindor, pottter, terror]
# 2        [mockingbird, kill, regional, pathos, rocked]
# 3       [austen, jane, elizabeth, quadrille, sparring]
# 4    [thirsted, unconditionally, extraordinarily, d...
# 5                [liesel, busier, books, foster, nazi]
# 6    [farm, slogans, totalitarianism, stalinist, ov...
# 7     [narnia, chronicles, books, lewis, chronlogical]
# 8            [r, baggins, gandalf, hobbit, fellowship]
# 9            [hara, sherman, scarlett, disposal, claw]
# Name: keywords, dtype: object

# %%
pip install keybert
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 78.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 63.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 791.0 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 58.6 MB/s eta 0:00:00
# ...

# %%
from keybert import KeyBERT
kw_model = KeyBERT()

def get_keywords(text):
    keywords = kw_model.extract_keywords(text, stop_words="english")
    keywords = " ".join([key for key, value in keywords])
    return keywords

books_data['keywords1'] = books_data['description'].apply(get_keywords)


# Please do not run this cell as it will interfere with the dataset

# %%
# Keywords from keybert are stored in another file due to long processing time

keybert_keywords = pd.read_csv("/content/drive/MyDrive/books/books_modified.csv", usecols = ['keywords1'])
keybert_keywords['keywords1'] = keybert_keywords['keywords1'].apply(lambda keywords: keywords.split())
keybert_keywords.head()
# Out:
#                                            keywords1
# 0       [katniss, hunger, winning, survival, losing]
# 1          [harry, darkness, terror, waking, dreams]
# 2  [mockingbird, literature, pulitzer, novel, bes...
# 3      [austen, novels, pride, prejudice, elizabeth]
# 4    [vampire, twilight, edward, suspenseful, blood]

# %% [markdown]
# We can see that tf idf has a better interpretation of the keywords, although it is often overfilled with characters names. a solution would be combining keywords from tf idf and keybert, or concatenating keywords from tf idf with characters names and settings.

# %%
books_data['keywords_comb'] = [
    list(set(k1 + k2))
    for k1, k2 in zip(books_data['keywords'], keybert_keywords['keywords1'])
]
books_data['keywords_comb'].head()
# Out:
# 0    [hunger, survival, losing, games, districts, k...
# 1    [terror, pottter, hogwarts, dreams, gryffindor...
# 2    [bestseller, pathos, pulitzer, literature, kil...
# 3    [quadrille, elizabeth, novels, pride, sparring...
# 4    [irrevocably, extraordinarily, vampire, domina...
# Name: keywords_comb, dtype: object

# %%
model.get_vector('vampire').shape
# Out:
# (50,)

# %%
def words_to_vector(words, model=model):
  vector = [model.get_vector(word) if word in model else np.zeros(model.vector_size)for word in words]
  return np.mean(vector, axis=0)

# %%
books_data['vector'] = books_data['keywords_comb'].apply(words_to_vector)

# %%
books_data['vector'].head()
# Out:
# 0    [0.25317225, 0.16850126, 0.08338297, -0.242857...
# 1    [-0.18038686644285917, 0.09375500865280628, 0....
# 2    [-0.10395223, 0.29649675, 0.24472398, 0.006274...
# 3    [-0.22893024887889624, -0.08616500347852707, 0...
# 4    [-0.6693780168890953, -0.07352045997977256, 0....
# Name: vector, dtype: object

# %%
books_data['vector'][1].shape
# Out:
# (50,)

# %%
from sklearn.neighbors import NearestNeighbors

nn = NearestNeighbors(n_neighbors=5, metric='cosine')
nn.fit(books_data['vector']) # This will throw an error since the model will only see
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only length-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3916456987.py in <cell line: 0>()
#       2
#       3 nn = NearestNeighbors(n_neighbors=5, metric='cosine')
# ----> 4 nn.fit(books_data['vector']) # This will throw an error since the model will only see
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_unsupervised.py in fit(self, X, y)
# ...

# %%
from sklearn.neighbors import NearestNeighbors

X = np.stack(books_data['vector'].values, axis=0)

nn = NearestNeighbors(n_neighbors=5, metric='cosine')
nn.fit(X)
# Out:
# NearestNeighbors(metric='cosine')

# %%
print("genres" in books_data.columns)
print(books_data.head(1))
# Out:
# True
#               title           author  rating  \
# 0  The Hunger Games  suzanne collins    4.33
#
#                                          description language  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English
#
#                                               genres  numRatings  length  \
# 0  [young adult, fiction, dystopia, fantasy, scie...     6376780     147
#
#                                        keywords  \
# 0  [katniss, districts, games, capitol, hunger]
#
#                                        keywords_comb  \
# 0  [hunger, survival, losing, games, districts, k...
#
#                                               vector
# 0  [0.25317225, 0.16850126, 0.08338297, -0.242857...

# %%
def get_preference():
  category = input("Do you want to look for recommendation according to author or genre? ")
  return category

def get_genres():
  genre = input("What kind of book genre do you like? If you want to put in 2 or more genres please separate them with a comma. ")
  return genre

def genre_match(gs, genre_input):
    return all(g.lower() in (x.lower() for x in gs) for g in genre_input)

def get_author():
  author = input("Who is the author you want to look for? ")
  return author

def get_keywords():
  keywords = input("What are the keywords you want to look for? ")
  return keywords.split()

def get_recommendation(user_input):
  if 'selected_idx' in user_input:
    selected_idx = user_input['selected_idx']
    book_vector = books_data.loc[selected_idx, 'vector']
    distances, indices = nn.kneighbors([book_vector]) # For two dimensional array as input
    recommended_books = books_data.loc[indices.flatten()[1:], ['title', 'author']]
  else :
    keywords = user_input['keywords']
    user_vector = words_to_vector(keywords)
    distances, indices = nn.kneighbors([user_vector])
    recommended_books = books_data.loc[indices.flatten(), ['title', 'author']]

  return recommended_books

def show_books(book_list):
        for idx, row in book_list.iterrows():
            print(f"{idx}: {row['title']} by {row['author']} (Genres: {', '.join(row['genres'])})")

def ablauf():
  user_input = {}
  preference = get_preference().lower()
  if preference == 'genre':
        genre_input = get_genres().lower().split(',')
        genre_input = [g.strip() for g in genre_input]
        print("User input:", genre_input)
        print("First book genres:", books_data['genres'].iloc[0])

        filtered_books = books_data[books_data['genres'].apply(lambda gs: genre_match(gs, genre_input))]

  elif preference == 'author':
        author_input = get_author().lower().strip()
        filtered_books = books_data[books_data['author'].str.contains(author_input)]

  else:
        print("Invalid preference. Please choose 'author' or 'genre'.")
        return None

  top_books = filtered_books.sort_values('rating_total', ascending=False).head(5)
  for idx, row in top_books.iterrows():
            print(f"{idx}: {row['title']} by {row['author']} (Genres: {', '.join(row['genres'])})")
  selected_idx = input("Pick the number of the book you like the most (or type 'none'):")

  if selected_idx.lower() == 'none':
        next_books = filtered_books.sort_values('rating', ascending=False).iloc[5:10]
        print("Here are the next 5 books:")
        for idx, row in next_books.iterrows():
            print(f"{idx}: {row['title']} by {row['author']} (Genres: {', '.join(row['genres'])})")
        selected_idx = input("Pick the number of the book you like the most (or type 'none'):")

  if selected_idx.lower() == 'none':
        keywords_input = get_keywords()
        user_input = {'keywords': keywords_input}
        recommendeds = get_recommendation(user_input)
        print("Here are the recommended books based on your keywords:")
        show_books(recommendeds))
        return recommendeds

  selected_idx = int(selected_idx)
  user_input['selected_idx'] = selected_idx
  selected_book = books_data.loc[selected_idx]
  print(f"You selected: {selected_book['title']} by {selected_book['author']}")

  recommendeds = get_recommendation(user_input)
  print("Here are the recommended books:")
  show_books(recommendeds)

  return recommendeds

# %%
print(genre_match(['young adult', 'fiction'], ['young adult']))
# Out:
# True

# %%
if __name__ == "__main__":
    ablauf()
# Out:
# Do you want to look for recommendation according to author or genre? genre
# What kind of book genre do you like? If you want to put in 2 or more genres please separate them with a comma. young adult, romance
# User input: ['young adult', 'romance']
# First book genres: ['young adult', 'fiction', 'dystopia', 'fantasy', 'science fiction', 'romance', 'adventure', 'teen', 'post apocalyptic', 'action']
# 0: The Hunger Games by suzanne collins (Genres: young adult, fiction, dystopia, fantasy, science fiction, romance, adventure, teen, post apocalyptic, action)
# 4: Twilight by stephenie meyer (Genres: young adult, fantasy, romance, vampires, fiction, paranormal, paranormal romance, supernatural, teen, urban fantasy)
# 10: The Fault in Our Stars by john green (goodreads author) (Genres: young adult, romance, fiction, contemporary, realistic fiction, teen, coming of age, drama, novels, love)
# ...
